# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_excel('Data_Train.xlsx')

# %%
train_data.shape
# Out:
# (11094, 9)

# %%
train_data.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
train_data.dtypes
# Out:
# Restaurant       object
# Location         object
# Cuisines         object
# Average_Cost     object
# Minimum_Order    object
# Rating           object
# Votes            object
# Reviews          object
# Delivery_Time    object
# dtype: object

# %%
train_data.isnull().sum()
# Out:
# Restaurant       0
# Location         0
# Cuisines         0
# Average_Cost     0
# Minimum_Order    0
# Rating           0
# Votes            0
# Reviews          0
# Delivery_Time    0
# dtype: int64

# %%
train_data.nunique()
# Out:
# Restaurant       7480
# Location           35
# Cuisines         2179
# Average_Cost       26
# Minimum_Order      18
# Rating             33
# Votes            1103
# Reviews           761
# Delivery_Time       7
# dtype: int64

# %%
for col in train_data.columns:
    print(col,train_data[col].value_counts())
# Out:
# Restaurant ID_7184    22
# ID_7295    20
# ID_4625    20
# ID_5321    19
# ID_5538    19
# ID_2483    18
# ID_2301    17
# ID_4654    16
# ID_7544    16
# ID_1140    16
# ID_8511    15
# ID_1209    15
# ID_188     15
# ID_7750    14
# ID_3970    14
# ID_5708    14
# ID_7564    13
# ID_5952    13
# ID_3969    13
# ID_2794    12
# ID_4906    12
# ID_720     12
# ID_7260    12
# ID_686     11
# ID_5885    11
# ID_4652    11
# ID_4446    11
# ID_6229    11
# ID_2542    11
# ID_8605    10
#            ..
# ID_959      1
# ID_3620     1
# ID_2499     1
# ID_3534     1
# ID_2100     1
# ID_3874     1
# ID_83       1
# ID_6506     1
# ID_3664     1
# ID_5970     1
# ID_5345     1
# ID_6817     1
# ID_5509     1
# ID_7566     1
# ID_742      1
# ID_1590     1
# ID_8213     1
# ID_2901     1
# ID_7710     1
# ID_2504     1
# ID_3352     1
# ID_6543     1
# ID_6226     1
# ID_1603     1
# ID_1495     1
# ID_638      1
# ID_5004     1
# ID_4536     1
# ID_4863     1
# ID_4259     1
# ...

# %%
train_data[train_data['Restaurant'] == 'ID_7295']
# Out:
#       Restaurant                                    Location  \
# 349      ID_7295        Noorkhan Bazaar, Malakpet, Hyderabad
# 722      ID_7295             Musi Nagar, Malakpet, Hyderabad
# 1619     ID_7295                          Sector 63A,Gurgaon
# 2000     ID_7295           Hyderabad Public School, Begumpet
# 4286     ID_7295                Delhi High Court, India Gate
# 4360     ID_7295           Nathan Road, Mangaldas Road, Pune
# 4482     ID_7295                   D-Block, Sector 63, Noida
# 5151     ID_7295                            Sector 14, Noida
# 5321     ID_7295             Jaya Nagar, Saidabad, Hyderabad
# 5682     ID_7295        Panjetan Colony, Malakpet, Hyderabad
# 6383     ID_7295          Rmz Centennial, I Gate, Whitefield
# 7852     ID_7295          Chatta Bazaar, Malakpet, Hyderabad
# 8432     ID_7295                               MG Road, Pune
# 8568     ID_7295  Mico Layout, Stage 2, BTM Layout,Bangalore
# ...

# %%
train_data[train_data.Restaurant.str.startswith('ID')].shape
# Out:
# (11094, 9)

# %%
def clean_average_cost(value):
    value = value[1:]
    if ',' in value:
        value = value.replace(',','')
    return int(value)

# %%
train_data[train_data.Average_Cost == 'for']
# Out:
#      Restaurant         Location   Cuisines Average_Cost Minimum_Order Rating  \
# 6297    ID_6472  Pune University  Fast Food          for           ₹50    NEW
#
#      Votes Reviews Delivery_Time
# 6297     -       -    30 minutes

# %%
train_data[train_data.Restaurant == 'ID_6472']
# Out:
#      Restaurant                   Location   Cuisines Average_Cost  \
# 5988    ID_6472  D-Block, Sector 63, Noida  Fast Food         ₹200
# 6297    ID_6472            Pune University  Fast Food          for
#
#      Minimum_Order Rating Votes Reviews Delivery_Time
# 5988           ₹99    3.7  1056     329    65 minutes
# 6297           ₹50    NEW     -       -    30 minutes

# %%
train_data[(train_data.Location == 'Pune University') 
           & (train_data.Cuisines == 'Fast Food') 
           & (train_data.Minimum_Order == '₹50') 
           & (train_data.Delivery_Time == '30 minutes')]
# Out:
#       Restaurant         Location   Cuisines Average_Cost Minimum_Order  \
# 794      ID_4886  Pune University  Fast Food         ₹200           ₹50
# 948      ID_7655  Pune University  Fast Food         ₹100           ₹50
# 1910     ID_2989  Pune University  Fast Food         ₹100           ₹50
# 3193     ID_8161  Pune University  Fast Food         ₹150           ₹50
# 3278     ID_1185  Pune University  Fast Food         ₹100           ₹50
# 5256     ID_6482  Pune University  Fast Food         ₹100           ₹50
# 5495     ID_8147  Pune University  Fast Food         ₹100           ₹50
# 6142     ID_8328  Pune University  Fast Food         ₹200           ₹50
# 6297     ID_6472  Pune University  Fast Food          for           ₹50
# 6694     ID_7023  Pune University  Fast Food         ₹200           ₹50
# 7718       ID_15  Pune University  Fast Food         ₹100           ₹50
# 9064     ID_6526  Pune University  Fast Food          ₹50           ₹50
# ...

# %%
# 100 is the mode. So we will replace for with 100

# %%
train_data.Average_Cost = train_data.Average_Cost.str.replace('for', '₹100')

# %%
train_data[train_data.Average_Cost == 'for']
# Out:
# Empty DataFrame
# Columns: [Restaurant, Location, Cuisines, Average_Cost, Minimum_Order, Rating, Votes, Reviews, Delivery_Time]
# Index: []

# %%
train_data.Average_Cost = train_data.Average_Cost.apply(clean_average_cost)

# %%
train_data.Average_Cost.value_counts()
# Out:
# 200     3241
# 100     2558
# 150     2462
# 250      881
# 300      537
# 350      283
# 400      282
# 50       265
# 600      154
# 500      101
# 450       63
# 550       60
# 650       55
# 800       44
# 750       38
# 900       15
# 700       15
# 850       12
# 1000      12
# 1200       8
# 950        4
# 1150       1
# 1400       1
# 1100       1
# 2050       1
# Name: Average_Cost, dtype: int64

# %%
train_data.Minimum_Order.value_counts()
# Out:
# ₹50     10118
# ₹99       779
# ₹0        158
# ₹199        8
# ₹200        8
# ₹59         3
# ₹299        3
# ₹350        3
# ₹450        2
# ₹90         2
# ₹79         2
# ₹300        2
# ₹500        1
# ₹89         1
# ₹240        1
# ₹250        1
# ₹400        1
# ₹150        1
# Name: Minimum_Order, dtype: int64

# %%
train_data.Minimum_Order = train_data.Minimum_Order.apply(clean_average_cost)

# %%
train_data.Minimum_Order.value_counts()
# Out:
# 50     10118
# 99       779
# 0        158
# 200        8
# 199        8
# 299        3
# 59         3
# 350        3
# 300        2
# 79         2
# 90         2
# 450        2
# 500        1
# 250        1
# 150        1
# 89         1
# 400        1
# 240        1
# Name: Minimum_Order, dtype: int64

# %%
train_data.Rating.value_counts()
# Out:
# -                     1191
# 3.7                    869
# 3.6                    846
# 3.5                    818
# 3.8                    800
# NEW                    758
# 3.9                    749
# 3.4                    718
# 3.3                    675
# 4.0                    614
# 3.2                    511
# 4.1                    459
# 3.1                    411
# 3.0                    302
# 4.2                    272
# 4.3                    247
# 2.9                    199
# 2.8                    157
# 4.4                    142
# 4.5                     78
# 2.7                     76
# 2.6                     42
# 4.6                     41
# 4.7                     36
# 2.5                     27
# 2.4                     13
# 4.8                     13
# Opening Soon            12
# 4.9                      8
# 2.3                      6
# Temporarily Closed       2
# 2.1                      1
# 2.2                      1
# Name: Rating, dtype: int64

# %%
train_data.Delivery_Time.value_counts()
# Out:
# 30 minutes     7406
# 45 minutes     2665
# 65 minutes      923
# 120 minutes      62
# 20 minutes       20
# 80 minutes       14
# 10 minutes        4
# Name: Delivery_Time, dtype: int64

# %%
sample_sub = pd.read_excel('Sample_Submission.xlsx')

# %%
sample_sub.head()
# Out:
#   Delivery_Time
# 0   120 minutes
# 1    20 minutes
# 2    20 minutes
# 3    65 minutes
# 4    45 minutes

# %%
sample_sub.Delivery_Time.unique()
# Out:
# array(['120 minutes', '20 minutes', '65 minutes', '45 minutes',
#        '30 minutes', '80 minutes', '10 minutes'], dtype=object)

# %%
#Votes	Reviews

train_data.Votes.value_counts().head()
# Out:
# -    2074
# 4     248
# 6     200
# 7     182
# 9     181
# Name: Votes, dtype: int64

# %%
train_data[train_data.Votes == '-'].shape
# Out:
# (2074, 9)

# %%
train_data[train_data.Reviews == '-'].shape
# Out:
# (2312, 9)

# %%
train_data[train_data.Rating == '-'].shape
# Out:
# (1191, 9)

# %%
train_data.plot(x= 'Average_Cost', kind = 'hist')

# %%
train_data.Cuisines.value_counts()
# Out:
# North Indian                                                               850
# North Indian, Chinese                                                      614
# Fast Food                                                                  434
# South Indian                                                               270
# Chinese                                                                    245
# Street Food                                                                181
# Bakery, Desserts                                                           171
# Bakery                                                                     168
# North Indian, Mughlai                                                      155
# Pizza, Fast Food                                                           133
# Chinese, North Indian                                                      125
# Fast Food, Beverages                                                       114
# ...

# %%
train_data.Cuisines = train_data.Cuisines.apply(lambda x:x.lower())

# %%
train_data.Cuisines.value_counts().head()
# Out:
# north indian             850
# north indian, chinese    614
# fast food                434
# south indian             270
# chinese                  245
# Name: Cuisines, dtype: int64

# %%
def get_cuisine_list(value):
    cuisine_dic = {}
